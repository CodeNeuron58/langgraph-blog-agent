# %%
from __future__ import annotations

# Import the ChatGroq class from the langchain_groq package
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

from typing import TypedDict, List, Annotated
from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
class Task(BaseModel):
    id: str
    title: str
    brief: str = Field(description="What to Cover in the blog post")

# %%
class Plan(BaseModel):
    blog_title: str
    tasks: List[Task]

# %%
import operator

class State(TypedDict):
    topic: str
    plan: Plan
    # task: Task  # for individual worker execution
    sections: Annotated[List[str], operator.add]
    final: str

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
llm.invoke("Good Morning")
# Out:
# AIMessage(content='Good morning! How can I assist you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 37, 'total_tokens': 48, 'completion_time': 0.013930392, 'completion_tokens_details': None, 'prompt_time': 0.003229794, 'prompt_tokens_details': None, 'queue_time': 0.168246926, 'total_time': 0.017160186}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c2e21-2608-7d10-9b5c-b88527c645d7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 11, 'total_tokens': 48})

# %%
def orchestrator(state: State):
    plan = llm.with_structured_output(Plan).invoke(
        [
            SystemMessage(
                content=(
                    "You are an experienced technical writer who creates clear, friendly, and engaging blog plans. "
                    "Your audience includes recruiters, hiring managers, and professionals who prefer concise, readable content. "
                    "Avoid jargon-heavy language. Focus on clarity, real-world relevance, and logical flow."
                )
            ),
            HumanMessage(
                content=(
                    f"Create a blog outline with 6–7 well-structured sections on the topic below.\n\n"
                    f"Topic: {state['topic']}\n\n"
                    "Each section should:\n"
                    "- Have a clear, engaging title\n"
                    "- Include a short 1–2 sentence description\n"
                    "- Be written in a friendly, conversational tone\n"
                    "- Emphasize practical insights and real-world value\n\n"
                    "The outline should feel approachable, professional, and easy to skim."
                )
            )
        ]
    )
    return {"plan":plan}

# %%
# Visualize(orchestrator)

# %%
plan = llm.with_structured_output(Plan).invoke(
    [
        SystemMessage(
            content=(
                "You are an experienced technical writer who creates clear, friendly, and engaging blog plans. "
                "Your audience includes recruiters, hiring managers, and professionals who prefer concise, readable content. "
                "Avoid jargon-heavy language. Focus on clarity, real-world relevance, and logical flow."
            )
        ),
        HumanMessage(
            content=(
                f"Create a blog outline with 6–7 well-structured sections on the topic below.\n\n"
                f"Topic: agentic AI \n\n"
                "Each section should:\n"
                "- Have a clear, engaging title\n"
                "- Include a short 1–2 sentence description\n"
                "- Be written in a friendly, conversational tone\n"
                "- Emphasize practical insights and real-world value\n\n"
                "The outline should feel approachable, professional, and easy to skim."
            )
        )
    ]
)

# %%
plan.blog_title
# Out:
# 'Unlocking the Power of Agentic AI: A Guide to Smarter Automation'

# %%
plan.tasks
# Out:
# [Task(id='1', title='Introduction to Agentic AI', brief='Explore the concept of agentic AI and its potential to revolutionize automation, highlighting its benefits and applications in real-world scenarios.'),
#  Task(id='2', title='Understanding Agency in AI', brief='Dive into the definition and implications of agency in AI, discussing how it enables machines to make decisions and take actions autonomously.'),
#  Task(id='3', title='The Future of Work with Agentic AI', brief='Discuss the impact of agentic AI on the job market, including the creation of new job opportunities and the need for workers to develop new skills.'),
#  Task(id='4', title='Agentic AI in Action: Real-World Examples', brief='Examine practical examples of agentic AI in various industries, such as healthcare, finance, and transportation, highlighting its potential to drive innovation and efficiency.'),
#  Task(id='5', title='Overcoming Challenges and Concerns', brief='Address the challenges and concerns surrounding agentic AI, including ethical considerations, security risks, and the need for transparency and accountability.'),
#  Task(id='6', title='Preparing for an Agentic AI-Driven World', brief='Offer guidance on how individuals and organizations can prepare for the integration of agentic AI, including strategies for upskilling and reskilling.'),
#  Task(id='7', title='Conclusion: Embracing the Potential of Agentic AI', brief='Summarize the key takeaways and emphasize the importance of embracing agentic AI as a catalyst for growth, innovation, and progress.')]

# %%
def task_distributor(state: State):
    """
    Dynamically creates one worker per task.
    The number of workers equals the number of sections in the plan.
    """

    tasks = state["plan"].tasks

    # Create one Send event per task
    sends = [
        Send(
            "section_writer",  # name of the worker node
            {
                "topic": state["topic"],
                "task": task,  # pass individual task
                "plan": state["plan"],
            },
        )
        for task in tasks
    ]

    return sends

# %%
def worker(payload: dict):
    task = payload["task"]
    plan = payload["plan"]
    topic = payload["topic"]
    
    # write the section
    section_md = llm.invoke(
        [
            SystemMessage(
                content=(
                    "write one clean markdown section"
                )
            ),
            HumanMessage(
                content=(
                    f"Write a blog section on the topic below in markdown only.\n\n"
                    f"Blog: {plan.blog_title}\n\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n\n"
                    f"Description: {task.brief}\n\n"
                )
            )
        ]
    ).content.strip()
    
    return {"sections": [section_md]}

# %%
from pathlib import Path


def finalizer(state: State):
    title = state["plan"].blog_title
    sections = state["sections"]
    final_md = f"# {title}\n\n" + "\n\n".join(sections)
    
    # save file
    file_name = title.lower().replace(" ", "_").replace(":", "").replace("'", "") + ".md"
    Path(file_name).write_text(final_md, encoding="utf-8")
    
    return {"final": final_md}

# %%
graph = StateGraph(State)


graph.add_node("orchestrator", orchestrator)
graph.add_node("section_writer", worker)
graph.add_node("finalizer", finalizer)

graph.add_edge(START, "orchestrator")
graph.add_conditional_edges(
    "orchestrator",
    task_distributor,
    ["section_writer"]
)

graph.add_edge("section_writer", "finalizer")
graph.add_edge("finalizer", END)

app = graph.compile()

# %%
blog = app.invoke({"topic": "langgraph","sections":[]})

# %%
blog
# Out:
# {'topic': 'langgraph',
#  'plan': Plan(blog_title="Unlocking the Power of Langgraph: A Beginner's Guide", tasks=[Task(id='1', title='Introduction to Langgraph', brief='Discover what Langgraph is and its significance in the industry, with a brief overview of its applications and benefits.'), Task(id='2', title='Getting Started with Langgraph', brief='Learn how to set up Langgraph and start exploring its features, with step-by-step instructions and tips for beginners.'), Task(id='3', title='Langgraph in Action: Real-World Examples', brief='Explore real-world examples of Langgraph in use, highlighting its practical applications and the value it can bring to businesses and individuals.'), Task(id='4', title='Tips and Tricks for Mastering Langgraph', brief='Get expert advice on how to get the most out of Langgraph, including tips on optimization, customization, and integration with other tools.'), Task(id='5', title='Common Challenges and Solutions', brief='Address common challenges and pitfalls when working with Langgraph, and learn how to troubleshoot and overcome them.'), Task(id='6', title='The Future of Langgraph: Trends and Predictions', brief='Stay ahead of the curve with insights into the future of Langgraph, including emerging trends, predicted developments, and potential applications.'), Task(id='7', title='Conclusion: Unlocking the Full Potential of Langgraph', brief='Summarize the key takeaways from the guide and encourage readers to start exploring Langgraph and unlocking its full potential.')]),
#  'sections': ['### Introduction to Langgraph\n#### What is Langgraph?\nLanggraph is a revolutionary technology that has been gaining momentum in recent years, particularly in the fields of natural language processing and artificial intelligence. At its core, Langgraph is a graph-based approach to representing and analyzing language, allowing for more efficient and effective processing of complex linguistic structures.\n\n#### Significance in the Industry\nThe significance of Langgraph lies in its ability to unlock new possibilities for language understanding and generation. By representing language as a graph, Langgraph enables the development of more sophisticated language models, chatbots, and other AI-powered applications. This has far-reaching implications for industries such as customer service, language translation, and content creation.\n\n#### Applications and Benefits\nSome of the key applications of Langgraph include:\n* **Improved language understanding**: Langgraph enables machines to better comprehend the nuances of human language, leading to more accurate and effective language processing.\n* **Enhanced language generation**: Langgraph facilitates the generation of more coherent and contextually relevant text, making it an ideal tool for applications such as chatbots and content creation.\n* **Increased efficiency**: By representing language as a graph, Langgraph reduces the computational complexity associated with traditional language processing methods, resulting in faster and more efficient processing times.',
#   "### Getting Started with Langgraph\n#### Introduction to Langgraph Setup\nTo begin your journey with Langgraph, follow these simple steps to set up your environment:\n1. **Install Langgraph**: Download and install the Langgraph software from the official website, ensuring you have the necessary system requirements.\n2. **Configure Your Settings**: Launch Langgraph and configure your settings, including choosing your preferred language and setting up your workspace.\n3. **Explore the Interface**: Familiarize yourself with the Langgraph interface, including the toolbar, menu options, and main workspace area.\n#### Initial Tips for Beginners\n* **Start with Tutorials**: Complete the introductory tutorials to gain hands-on experience with Langgraph's core features.\n* **Experiment with Examples**: Try out the example projects provided to understand how Langgraph can be applied to real-world scenarios.\n* **Join the Community**: Connect with other Langgraph users through online forums or social media groups to learn from their experiences and stay updated on new developments.",
#   "### Langgraph in Action: Real-World Examples\nLanggraph is being used in various industries to improve language understanding and generation. Here are a few examples:\n* **Language Translation**: Langgraph is used in translation software to provide more accurate and natural-sounding translations.\n* **Chatbots and Virtual Assistants**: Langgraph is used to power chatbots and virtual assistants, allowing them to better understand and respond to user queries.\n* **Text Summarization**: Langgraph is used to summarize long pieces of text into concise and meaningful summaries.\n* **Content Generation**: Langgraph is used to generate high-quality content, such as articles and social media posts, saving businesses time and resources.\n* **Sentiment Analysis**: Langgraph is used to analyze customer sentiment, allowing businesses to better understand their customers' needs and preferences.",
#   "### Tips and Tricks for Mastering Langgraph\nLanggraph is a powerful tool that can help you unlock new insights and improve your workflow, but getting the most out of it requires some expertise. Here are some tips and tricks to help you master Langgraph:\n* **Optimization**: To get the most out of Langgraph, it's essential to optimize your workflow. This includes setting up your data sources correctly, using the right algorithms, and fine-tuning your parameters.\n* **Customization**: Langgraph allows for a high degree of customization, which can be both a blessing and a curse. To get the most out of it, focus on customizing the features that matter most to your workflow, and don't be afraid to experiment and try new things.\n* **Integration**: Langgraph can be integrated with a wide range of other tools and platforms, which can help you streamline your workflow and get more done in less time. Consider integrating Langgraph with other tools you already use, such as data visualization software or project management platforms.\n* **Practice**: Like any skill, mastering Langgraph takes practice. Don't be discouraged if it takes time to get the hang of it - keep experimenting, learning, and pushing yourself to get the most out of the tool.\n* **Community**: Finally, don't forget to tap into the Langgraph community for support and guidance. There are many online forums, tutorials, and resources available to help you learn and master Langgraph.",
#   '### Common Challenges and Solutions\n#### Introduction to Challenges\nLanggraph, like any other powerful tool, comes with its own set of challenges and pitfalls. Understanding these challenges is crucial for effective troubleshooting and ensuring a smooth workflow. In this section, we will delve into common issues encountered when working with Langgraph and provide practical solutions to overcome them.\n\n#### Data Quality Issues\n* **Inconsistent Data**: Langgraph relies heavily on high-quality, consistent data to produce accurate results. Inconsistent data can lead to poor model performance.\n\t+ **Solution**: Implement rigorous data cleaning and preprocessing techniques to ensure data consistency and quality.\n* **Insufficient Data**: Working with limited data can hinder the performance of Langgraph models.\n\t+ **Solution**: Explore data augmentation techniques or consider collecting additional data to enhance model training.\n\n#### Model Complexity and Overfitting\n* **Overly Complex Models**: Models that are too complex can suffer from overfitting, leading to poor performance on unseen data.\n\t+ **Solution**: Regularly monitor model performance on validation sets and adjust complexity by tweaking hyperparameters or simplifying the model architecture.\n* **Underfitting**: Conversely, models that are too simple may fail to capture the underlying patterns in the data.\n\t+ **Solution**: Gradually increase model complexity or explore different architectures that can better fit the data.\n\n#### Computational Resources and Efficiency\n* **High Computational Requirements**: Training large Langgraph models can be computationally intensive, requiring significant resources.\n\t+ **Solution**: Leverage distributed computing, utilize GPU acceleration, or consider cloud services that offer scalable computational resources.\n* **Inefficient Model Serving**: Serving models can sometimes be inefficient, especially in production environments.\n\t+ **Solution**: Optimize model serving by using model pruning, quantization, or deploying models on specialized hardware designed for inference.\n\n#### Troubleshooting Tips\n* **Monitor Performance Metrics**: Keep a close eye on key performance metrics to quickly identify when issues arise.\n* **Log and Analyze Errors**: Detailed logging and error analysis can provide insights into the root causes of problems.\n* **Community and Documentation**: Leverage the Langgraph community, official documentation, and forums for troubleshooting guidance and best practices.\n\nBy understanding these common challenges and applying the suggested solutions, users can more effectively navigate the complexities of working with Langgraph, ensuring they unlock its full potential for their projects.',
#   "### The Future of Langgraph: Trends and Predictions\nLanggraph is rapidly evolving, and understanding its future trajectory is crucial for maximizing its potential. Here are some emerging trends, predicted developments, and potential applications that will shape the future of Langgraph:\n* **Increased Adoption**: As Langgraph becomes more mainstream, we can expect to see increased adoption across various industries, including healthcare, finance, and education.\n* **Advancements in Natural Language Processing**: Future developments in NLP will enable Langgraph to better understand nuances of human language, leading to more accurate and efficient processing of complex queries.\n* **Integration with Other AI Technologies**: Langgraph is likely to be integrated with other AI technologies, such as computer vision and machine learning, to create more comprehensive and powerful systems.\n* **Rise of Specialized Langgraph Models**: We can expect to see the development of specialized Langgraph models tailored to specific industries or use cases, such as medical Langgraph or financial Langgraph.\n* **Growing Importance of Explainability**: As Langgraph becomes more ubiquitous, there will be a growing need for explainability and transparency in its decision-making processes, leading to the development of more interpretable models.\n* **Potential Applications**: Langgraph has the potential to revolutionize various applications, including:\n  + **Virtual Assistants**: Langgraph can be used to create more sophisticated virtual assistants that can understand and respond to complex queries.\n  + **Language Translation**: Langgraph can be used to improve language translation systems, enabling more accurate and efficient communication across languages.\n  + **Text Summarization**: Langgraph can be used to summarize long pieces of text, extracting key information and insights.\n  + **Sentiment Analysis**: Langgraph can be used to analyze sentiment and emotion in text, enabling businesses to better understand their customers' needs and preferences.",
#   "### Conclusion: Unlocking the Full Potential of Langgraph\nIn this beginner's guide to Langgraph, we have explored the fundamental concepts and features that make it a powerful tool for language modeling and natural language processing. From understanding the basics of Langgraph to learning how to implement it in various applications, we have covered key takeaways that will help you get started on your Langgraph journey. \n* **Key Takeaways**: Langgraph offers a wide range of capabilities, including text generation, language translation, and sentiment analysis, making it a versatile tool for various industries and use cases.\n* **Unlocking Full Potential**: To unlock the full potential of Langgraph, it is essential to experiment with different models, fine-tune parameters, and explore various applications to find the best fit for your specific needs.\n* **Getting Started**: We encourage you to start exploring Langgraph today and discover the endless possibilities it has to offer. With its ease of use and extensive documentation, you can quickly get started and begin unlocking the power of Langgraph to drive innovation and growth in your projects and applications."],
#  'final': "# Unlocking the Power of Langgraph: A Beginner's Guide\n\n### Introduction to Langgraph\n#### What is Langgraph?\nLanggraph is a revolutionary technology that has been gaining momentum in recent years, particularly in the fields of natural language processing and artificial intelligence. At its core, Langgraph is a graph-based approach to representing and analyzing language, allowing for more efficient and effective processing of complex linguistic structures.\n\n#### Significance in the Industry\nThe significance of Langgraph lies in its ability to unlock new possibilities for language understanding and generation. By representing language as a graph, Langgraph enables the development of more sophisticated language models, chatbots, and other AI-powered applications. This has far-reaching implications for industries such as customer service, language translation, and content creation.\n\n#### Applications and Benefits\nSome of the key applications of Langgraph include:\n* **Improved language understanding**: Langgraph enables machines to better comprehend the nuances of human language, leading to more accurate and effective language processing.\n* **Enhanced language generation**: Langgraph facilitates the generation of more coherent and contextually relevant text, making it an ideal tool for applications such as chatbots and content creation.\n* **Increased efficiency**: By representing language as a graph, Langgraph reduces the computational complexity associated with traditional language processing methods, resulting in faster and more efficient processing times.\n\n### Getting Started with Langgraph\n#### Introduction to Langgraph Setup\nTo begin your journey with Langgraph, follow these simple steps to set up your environment:\n1. **Install Langgraph**: Download and install the Langgraph software from the official website, ensuring you have the necessary system requirements.\n2. **Configure Your Settings**: Launch Langgraph and configure your settings, including choosing your preferred language and setting up your workspace.\n3. **Explore the Interface**: Familiarize yourself with the Langgraph interface, including the toolbar, menu options, and main workspace area.\n#### Initial Tips for Beginners\n* **Start with Tutorials**: Complete the introductory tutorials to gain hands-on experience with Langgraph's core features.\n* **Experiment with Examples**: Try out the example projects provided to understand how Langgraph can be applied to real-world scenarios.\n* **Join the Community**: Connect with other Langgraph users through online forums or social media groups to learn from their experiences and stay updated on new developments.\n\n### Langgraph in Action: Real-World Examples\nLanggraph is being used in various industries to improve language understanding and generation. Here are a few examples:\n* **Language Translation**: Langgraph is used in translation software to provide more accurate and natural-sounding translations.\n* **Chatbots and Virtual Assistants**: Langgraph is used to power chatbots and virtual assistants, allowing them to better understand and respond to user queries.\n* **Text Summarization**: Langgraph is used to summarize long pieces of text into concise and meaningful summaries.\n* **Content Generation**: Langgraph is used to generate high-quality content, such as articles and social media posts, saving businesses time and resources.\n* **Sentiment Analysis**: Langgraph is used to analyze customer sentiment, allowing businesses to better understand their customers' needs and preferences.\n\n### Tips and Tricks for Mastering Langgraph\nLanggraph is a powerful tool that can help you unlock new insights and improve your workflow, but getting the most out of it requires some expertise. Here are some tips and tricks to help you master Langgraph:\n* **Optimization**: To get the most out of Langgraph, it's essential to optimize your workflow. This includes setting up your data sources correctly ...
