# %%
from __future__ import annotations

# Import the ChatGroq class from the langchain_groq package
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

from typing import TypedDict, List, Annotated, Literal
from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=5,
        description="3-5 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(
        ...,
        description="Target word count for this section (120–450).",
    )
    section_type: Literal[
        "intro", "core", "examples", "checklist", "common_mistakes", "conclusion"
    ] = Field(
        ...,
        description="Use 'common_mistakes' exactly once in the plan.",
    )

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str = Field(..., description="Who this blog is for.")
    tone: str = Field(..., description="Writing tone (e.g., practical, crisp).")
    tasks: List[Task]

# %%
import operator

class State(TypedDict):
    topic: str
    plan: Plan
    sections: Annotated[List[str], operator.add]  # reducer concatenates worker outputs
    final: str

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
llm.invoke("Good Morning")
# Out:
# AIMessage(content='Good morning! How can I assist you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 37, 'total_tokens': 48, 'completion_time': 0.021660729, 'completion_tokens_details': None, 'prompt_time': 0.000945394, 'prompt_tokens_details': None, 'queue_time': 0.050576966, 'total_time': 0.022606123}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c6516-dc72-73d0-97f7-c94d0a3d7a6d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 11, 'total_tokens': 48})

# %%
def orchestrator(state: State):
    plan = llm.with_structured_output(Plan).invoke(
        [
            SystemMessage(
                content=(
                    "You are an experienced technical writer who creates clear, friendly, and engaging blog plans. "
                    "Your audience includes recruiters, hiring managers, and professionals who prefer concise, readable content. "
                    "Avoid jargon-heavy language. Focus on clarity, real-world relevance, and logical flow."
                )
            ),
            HumanMessage(
                content=(
                    f"Create a blog outline with 6-7 well-structured sections on the topic below.\n\n"
                    f"Topic: {state['topic']}\n\n"
                    "Return a plan that matches this structure:\n"
                    "- blog_title: clear, engaging\n"
                    "- audience: who this blog is for\n"
                    "- tone: writing tone (e.g., practical, crisp)\n"
                    "- tasks: list of sections with fields:\n"
                    "  - id: integer\n"
                    "  - title: section title\n"
                    "  - goal: one-sentence outcome for the reader\n"
                    "  - bullets: 3-5 concrete, non-overlapping subpoints\n"
                    "  - target_words: 120-450\n"
                    "  - section_type: one of intro, core, examples, checklist, common_mistakes, conclusion\n"
                    "Use 'common_mistakes' exactly once in the tasks list.\n\n"
                    "Tone should be friendly, conversational, and practical. The outline should feel approachable, professional, and easy to skim."
                )
            ),
        ]
    )
    return {"plan": plan}

# %%
# Visualize(orchestrator)

# %%
plan = llm.with_structured_output(Plan).invoke(
    [
        SystemMessage(
            content=(
                "You are an experienced technical writer who creates clear, friendly, and engaging blog plans. "
                "Your audience includes recruiters, hiring managers, and professionals who prefer concise, readable content. "
                "Avoid jargon-heavy language. Focus on clarity, real-world relevance, and logical flow."
            )
        ),
        HumanMessage(
            content=(
                f"Create a blog outline with 6-7 well-structured sections on the topic below.\n\n"
                f"Topic: agentic AI \n\n"
                "Return a plan that matches this structure:\n"
                "- blog_title: clear, engaging\n"
                "- audience: who this blog is for\n"
                "- tone: writing tone (e.g., practical, crisp)\n"
                "- tasks: list of sections with fields:\n"
                "  - id: integer\n"
                "  - title: section title\n"
                "  - goal: one-sentence outcome for the reader\n"
                "  - bullets: 3-5 concrete, non-overlapping subpoints\n"
                "  - target_words: 120-450\n"
                "  - section_type: one of intro, core, examples, checklist, common_mistakes, conclusion\n"
                "Use 'common_mistakes' exactly once in the tasks list.\n\n"
                "Tone should be friendly, conversational, and practical. The outline should feel approachable, professional, and easy to skim."
            )
        ),
    ]
)

# %%
plan.blog_title
# Out:
# 'Unlocking the Power of Agentic AI: A Guide to Smarter Decision-Making'

# %%
plan.tasks
# Out:
# [Task(id=1, title='Introduction to Agentic AI', goal='The reader will understand the concept of agentic AI and its significance in modern technology', bullets=['Definition of agentic AI', 'Brief history and evolution of agentic AI', 'Importance of agentic AI in various industries'], target_words=200, section_type='intro'),
#  Task(id=2, title='Core Principles of Agentic AI', goal='The reader will be able to explain the core principles of agentic AI and how they enable decision-making', bullets=['Autonomy and self-directed learning', 'Goal-oriented behavior and decision-making', 'Adaptability and resilience in complex environments'], target_words=300, section_type='core'),
#  Task(id=3, title='Real-World Applications of Agentic AI', goal='The reader will be able to identify potential applications of agentic AI in their industry or field', bullets=['Healthcare and medical diagnosis', 'Financial analysis and portfolio management', 'Cybersecurity and threat detection'], target_words=250, section_type='examples'),
#  Task(id=4, title='Common Mistakes in Implementing Agentic AI', goal='The reader will be able to recognize and avoid common pitfalls in implementing agentic AI solutions', bullets=['Insufficient data quality and quantity', 'Inadequate testing and validation', 'Lack of transparency and explainability'], target_words=220, section_type='common_mistakes'),
#  Task(id=5, title='Best Practices for Agentic AI Development', goal='The reader will be able to apply best practices for developing and deploying agentic AI systems', bullets=['Collaborative development and stakeholder engagement', 'Continuous monitoring and evaluation', 'Ethical considerations and responsible AI development'], target_words=280, section_type='checklist'),
#  Task(id=6, title='The Future of Agentic AI: Trends and Opportunities', goal='The reader will be able to anticipate future developments and opportunities in agentic AI', bullets=['Advances in machine learning and natural language processing', 'Increased adoption in emerging industries and markets', 'Potential risks and challenges associated with agentic AI'], target_words=240, section_type='core'),
#  Task(id=7, title='Conclusion: Unlocking the Full Potential of Agentic AI', goal='The reader will be able to summarize the key takeaways and apply them to their own work or interests', bullets=['Key benefits and advantages of agentic AI', 'Actionable steps for getting started with agentic AI', 'Final thoughts and recommendations for further exploration'], target_words=180, section_type='conclusion')]

# %%
def task_distributor(state: State):
    """
    Dynamically creates one worker per task.
    The number of workers equals the number of sections in the plan.
    """

    tasks = state["plan"].tasks

    # Create one Send event per task
    sends = [
        Send(
            "section_writer",  # name of the worker node
            {
                "topic": state["topic"],
                "task": task,  # pass individual task
                "plan": state["plan"],
            },
        )
        for task in tasks
    ]

    return sends

# %%
def worker(payload: dict):
    task = payload["task"]
    plan = payload["plan"]
    topic = payload["topic"]

    bullets_text = "\n".join([f"- {item}" for item in task.bullets])

    # write the section
    section_md = llm.invoke(
        [
            SystemMessage(
                content=(
                    "Write one clean markdown section for a professional blog post."
                )
            ),
            HumanMessage(
                content=(
                    f"Write a blog section on the topic below in markdown only.\n\n"
                    f"Blog: {plan.blog_title}\n\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n\n"
                    "Must cover:\n"
                    f"{bullets_text}\n\n"
                    "Write in a clear, friendly, and practical voice. Avoid fluff and keep the section self-contained."
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
from pathlib import Path


def finalizer(state: State):
    title = state["plan"].blog_title
    sections = state["sections"]
    final_md = f"# {title}\n\n" + "\n\n".join(sections)
    
    # save file
    file_name = title.lower().replace(" ", "_").replace(":", "").replace("'", "") + ".md"
    Path(file_name).write_text(final_md, encoding="utf-8")
    
    return {"final": final_md}

# %%
graph = StateGraph(State)


graph.add_node("orchestrator", orchestrator)
graph.add_node("section_writer", worker)
graph.add_node("finalizer", finalizer)

graph.add_edge(START, "orchestrator")
graph.add_conditional_edges(
    "orchestrator",
    task_distributor,
    ["section_writer"]
)

graph.add_edge("section_writer", "finalizer")
graph.add_edge("finalizer", END)

app = graph.compile()

# %%
blog = app.invoke({"topic": "langgraph and langchain for building agentic ai system","sections":[]})

# %%
blog
# Out:
# {'topic': 'langgraph',
#  'plan': Plan(blog_title='Unlocking the Power of LangGraph: A Comprehensive Guide', audience='recruiters, hiring managers, and professionals', tone='friendly, conversational, and practical', tasks=[Task(id=1, title='Introduction to LangGraph', goal='The reader will understand the basic concept of LangGraph and its significance.', bullets=['Definition and explanation of LangGraph', 'Importance of LangGraph in natural language processing', 'Brief overview of LangGraph applications'], target_words=200, section_type='intro'), Task(id=2, title='Core Concepts of LangGraph', goal='The reader will be able to explain the core components and functionality of LangGraph.', bullets=['Graph structure and node relationships', 'Edge types and their roles in LangGraph', 'Node embeddings and their applications'], target_words=300, section_type='core'), Task(id=3, title='Real-World Applications of LangGraph', goal='The reader will understand the practical uses of LangGraph in various industries.', bullets=['Text classification and sentiment analysis', 'Named entity recognition and information extraction', 'Question answering and language translation'], target_words=250, section_type='examples'), Task(id=4, title='Common Mistakes in Implementing LangGraph', goal='The reader will be aware of common pitfalls and challenges when working with LangGraph.', bullets=['Insufficient data preprocessing', 'Inadequate model training and evaluation', 'Ignoring domain-specific requirements'], target_words=220, section_type='common_mistakes'), Task(id=5, title='Best Practices for Working with LangGraph', goal='The reader will learn how to effectively utilize LangGraph in their projects.', bullets=['Data quality and preprocessing techniques', 'Model selection and hyperparameter tuning', 'Interpretation and visualization of results'], target_words=280, section_type='checklist'), Task(id=6, title='Future Directions and Opportunities', goal='The reader will understand the potential future developments and applications of LangGraph.', bullets=['Advancements in graph neural networks', 'Integration with other AI technologies', 'Emerging applications in healthcare and finance'], target_words=230, section_type='core'), Task(id=7, title='Conclusion and Next Steps', goal='The reader will be able to summarize the key takeaways and plan their next steps with LangGraph.', bullets=['Summary of key concepts and applications', 'Resources for further learning and implementation', 'Encouragement to explore and experiment with LangGraph'], target_words=180, section_type='conclusion')]),
#  'sections': ['### Introduction to LangGraph\nLangGraph refers to a graphical representation of language, where words, phrases, and sentences are connected as nodes and edges in a network. This concept allows us to visualize and analyze the relationships between different linguistic elements, enabling a deeper understanding of language structure and meaning. In the realm of natural language processing, LangGraph plays a vital role in improving language models, sentiment analysis, and text classification. With LangGraph, applications such as chatbots, language translators, and text summarizers can be developed to better comprehend and generate human-like language. By harnessing the power of LangGraph, professionals can unlock new possibilities for language-based technologies, driving innovation and growth in various industries.',
#   "### Core Concepts of LangGraph\nTo unlock the full potential of LangGraph, it's essential to understand its core components and functionality. At its heart, LangGraph is a graph structure that represents language as a network of interconnected nodes and edges. \n#### Graph Structure and Node Relationships\nIn LangGraph, nodes typically represent words, phrases, or entities, while edges symbolize the relationships between them. These relationships can be syntactic, semantic, or pragmatic, capturing various aspects of language, such as grammar, meaning, and context. \n#### Edge Types and Their Roles\nThere are several edge types in LangGraph, each playing a unique role in representing language relationships. For example, **syntactic edges** connect words based on grammatical structure, while **semantic edges** link words with similar meanings. Understanding these edge types is crucial for effective LangGraph applications.\n#### Node Embeddings and Their Applications\nNode embeddings are vector representations of nodes in LangGraph, capturing their semantic properties and relationships. These embeddings have numerous applications, including **text classification**, **information retrieval**, and **question answering**. By leveraging node embeddings, you can unlock insights into language structure and meaning, enabling more accurate and efficient natural language processing tasks.",
#   '### Real-World Applications of LangGraph\nLangGraph has numerous practical applications across various industries, making it a valuable tool for professionals. Here are a few examples:\n* **Text Classification and Sentiment Analysis**: LangGraph can be used to analyze customer feedback, classify documents, and detect sentiment in text data. For instance, a company can use LangGraph to analyze product reviews and identify areas for improvement.\n* **Named Entity Recognition and Information Extraction**: LangGraph can extract specific information from unstructured text data, such as names, locations, and organizations. This can be useful in industries like finance, where extracting information from financial reports is crucial.\n* **Question Answering and Language Translation**: LangGraph can be used to build chatbots that answer customer queries and translate text from one language to another. This can be particularly useful in customer service, where providing support in multiple languages is essential.\nThese applications demonstrate the potential of LangGraph to streamline processes, improve customer experience, and gain valuable insights from text data. By leveraging LangGraph, professionals can unlock new possibilities and drive business growth.',
#   "### Common Mistakes in Implementing LangGraph\nWhen working with LangGraph, it's easy to get caught up in the excitement of exploring language models, but there are some common pitfalls to watch out for. Here are a few mistakes to avoid:\n* **Insufficient data preprocessing**: Failing to properly clean and preprocess your data can lead to subpar model performance. Make sure to handle missing values, remove unnecessary characters, and normalize your text data.\n* **Inadequate model training and evaluation**: Don't rush into deployment without thoroughly training and evaluating your model. Ensure you have a robust training dataset and use metrics like accuracy and F1-score to gauge performance.\n* **Ignoring domain-specific requirements**: LangGraph models can be highly effective, but they may not always understand the nuances of your specific industry or use case. Be sure to consider domain-specific requirements and fine-tune your model accordingly to achieve the best results.",
#   "### Best Practices for Working with LangGraph\nTo get the most out of LangGraph, follow these essential best practices:\n* **Ensure high-quality data**: Preprocess your data by handling missing values, removing duplicates, and normalizing text to improve model performance.\n* **Select the right model**: Choose a suitable LangGraph model based on your project's specific needs, such as language translation or text classification.\n* **Tune hyperparameters**: Experiment with different hyperparameter settings to optimize your model's performance and achieve better results.\n* **Visualize and interpret results**: Use visualization tools to understand your model's output and make informed decisions based on the insights gained from LangGraph.\n* **Monitor and update**: Continuously monitor your model's performance and update your approach as needed to maintain accuracy and relevance.\nBy following these best practices, you'll be able to unlock the full potential of LangGraph and drive success in your projects.",
#   '### Future Directions and Opportunities\nAs LangGraph continues to evolve, several exciting developments are on the horizon. One key area of advancement is in graph neural networks, which will enable LangGraph to better understand complex relationships between data points. Additionally, integrating LangGraph with other AI technologies, such as natural language processing and computer vision, will unlock new capabilities and applications. Emerging areas like healthcare and finance are also poised to benefit from LangGraph, with potential uses including predictive modeling for disease diagnosis and risk analysis for investment portfolios. By exploring these opportunities, professionals can harness the power of LangGraph to drive innovation and growth in their industries. With its potential to transform data analysis and decision-making, the future of LangGraph is bright, and its applications are vast and varied.',
#   "### Conclusion and Next Steps\nIn this comprehensive guide, we've explored the power of LangGraph and its applications in revolutionizing the way we work with language data. To recap, LangGraph is a game-changer for recruiters, hiring managers, and professionals, enabling them to extract insights, identify patterns, and make informed decisions. Key concepts include entity recognition, intent detection, and knowledge graph construction. With LangGraph, you can streamline recruitment processes, enhance candidate matching, and improve overall productivity. For further learning and implementation, check out online resources, such as tutorials, webinars, and case studies. We encourage you to explore and experiment with LangGraph, discovering new use cases and applications that can benefit your organization. Take the next step today and unlock the full potential of LangGraph."],
#  'final': "# Unlocking the Power of LangGraph: A Comprehensive Guide\n\n### Introduction to LangGraph\nLangGraph refers to a graphical representation of language, where words, phrases, and sentences are connected as nodes and edges in a network. This concept allows us to visualize and analyze the relationships between different linguistic elements, enabling a deeper understanding of language structure and meaning. In the realm of natural language processing, LangGraph plays a vital role in improving language models, sentiment analysis, and text classification. With LangGraph, applications such as chatbots, language translators, and text summarizers can be developed to better comprehend and generate human-like language. By harnessing the power of LangGraph, professionals can unlock new possibilities for language-based technologies, driving innovation and growth in various industries.\n\n### Core Concepts of LangGraph\nTo unlock the full potential of LangGraph, it's essential to understand its core components and functionality. At its heart, LangGraph is a graph structure that represents language as a network of interconnected nodes and edges. \n#### Graph Structure and Node Relationships\nIn LangGraph, nodes typically represent words, phrases, or entities, while edges symbolize the relationships between them. These relationships can be syntactic, semantic, or pragmatic, capturing various aspects of language, such as grammar, meaning, and context. \n#### Edge Types and Their Roles\nThere are several edge types in LangGraph, each playing a unique role in representing language relationships. For example, **syntactic edges** connect words based on grammatical structure, while **semantic edges** link words with similar meanings. Understanding these edge types is crucial for effective LangGraph applications.\n#### Node Embeddings and Their Applications\nNode embeddings are vector representations of nodes in LangGraph, capturing their semantic properties and relationships. These embeddings have numerous applications, including **text classification**, **information retrieval**, and **question answering**. By leveraging node embeddings, you can unlock insights into language structure and meaning, enabling more accurate and efficient natural language processing tasks.\n\n### Real-World Applications of LangGraph\nLangGraph has numerous practical applications across various industries, making it a valuable tool for professionals. Here are a few examples:\n* **Text Classification and Sentiment Analysis**: LangGraph can be used to analyze customer feedback, classify documents, and detect sentiment in text data. For instance, a company can use LangGraph to analyze product reviews and identify areas for improvement.\n* **Named Entity Recognition and Information Extraction**: LangGraph can extract specific information from unstructured text data, such as names, locations, and organizations. This can be useful in industries like finance, where extracting information from financial reports is crucial.\n* **Question Answering and Language Translation**: LangGraph can be used to build chatbots that answer customer queries and translate text from one language to another. This can be particularly useful in customer service, where providing support in multiple languages is essential.\nThese applications demonstrate the potential of LangGraph to streamline processes, improve customer experience, and gain valuable insights from text data. By leveraging LangGraph, professionals can unlock new possibilities and drive business growth.\n\n### Common Mistakes in Implementing LangGraph\nWhen working with LangGraph, it's easy to get caught up in the excitement of exploring language models, but there are some common pitfalls to watch out for. Here are a few mistakes to avoid:\n* **Insufficient data preprocessing**: Failing to properly clean and preprocess your data can lead to subpar model performance. Make sure to handle missing values, remove unnecessary cha ...
